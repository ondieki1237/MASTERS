# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient("mongodb+srv://accord1:Rkx5j3IwOXe0S8j0@cluster0.vn6ne8w.mongodb.net/accord_medical")

db = client["accord_medical"]

visits = list(db.visits.find())
facilities = list(db.facilities.find())

visits_df = pd.DataFrame(visits)
facilities_df = pd.DataFrame(facilities)

# %%
df = visits_df.merge(
    facilities_df,
    left_on="facilityId",
    right_on="_id",
    how="left"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_10030/729611561.py in ?()
# ----> 1 df = visits_df.merge(
#       2     facilities_df,
#       3     left_on="facilityId",
#       4     right_on="_id",
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
print(visits_df.columns)
# Out:
# Index(['_id', 'userId', 'visitId', 'date', 'startTime', 'client', 'contacts',
#        'visitPurpose', 'visitOutcome', 'notes', 'tags', 'isFollowUpRequired',
#        'followUpVisits', 'existingEquipment', 'requestedEquipment',
#        'attachments', 'photos', 'followUpActions', 'syncedAt', 'createdAt',
#        'updatedAt', '__v', 'productsOfInterest', 'endTime', 'duration'],
#       dtype='object')

# %%
df = df.drop(columns=['_id','__v','attachments','photos'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = df.drop(columns=['_id','__v','attachments','photos'])
#
# NameError: name 'df' is not defined

# %%
df = df.drop(columns=['_id','__v','attachments','photos'], errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = df.drop(columns=['_id','__v','attachments','photos'], errors='ignore')
#
# NameError: name 'df' is not defined

# %%
df = visits_df.drop(columns=['_id','__v','attachments','photos'], errors='ignore')

# %%
df['numProducts'] = df['productsOfInterest'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

# %%
X = df[['duration','numProducts','isFollowUpRequired']]
